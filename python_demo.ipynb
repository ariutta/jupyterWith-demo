# %%
a = 1
print(a)
# Out:
# 1

# %%
# Python program to demonstrate  
# basic array characteristics 
import numpy as np 
  
# Creating array object 
arr = np.array( [[ 1, 2, 3], 
                 [ 4, 2, 5]] )

# %%
# %load_ext sql
print("hi")
# Out:
# hi

# %%
import jupyterlab_sql
